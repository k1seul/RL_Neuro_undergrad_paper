# %%
from matplotlib import pyplot as plt
import math
import numpy as np

# %%
negative_p = 0.1 
log_weights = np.array([1, 2, 3, 4])
log_bias = log_weights * math.log(negative_p + 0.1)

# %%
dx = np.arange(0, 1, 0.01)
plt.figure(figsize=(10,8))
for i in range(len(log_weights)):
    dy = -log_weights[i] * np.log(dx + 0.1) + log_bias[i]
    plt.plot(dx,dy,label=f"log weight = {log_weights[i]}", linewidth=2)
    
plt.axhline(y=0, color='k', linewidth=2)
plt.axvline(x=0.1, color='b', linewidth=2, label="p = 0.1")
plt.xlim([0,1])
plt.yticks(np.arange(-5, 4, 1))
plt.xticks(np.arange(0, 1, 0.1))
plt.xlabel("probability", fontdict = {'fontsize' : 12})
plt.ylabel("internal reward", fontdict = {'fontsize' : 12})
plt.title("Internal Reward Function", fontdict = {'fontsize' : 15})
plt.legend()

# %%
# Out:
# array([ 0.69314718,  0.597837  ,  0.51082562,  0.43078292,  0.35667494,
#         0.28768207,  0.22314355,  0.16251893,  0.10536052,  0.05129329,
#         0.        , -0.04879016, -0.09531018, -0.13976194, -0.18232156,
#        -0.22314355, -0.26236426, -0.30010459, -0.33647224, -0.37156356,
#        -0.40546511, -0.43825493, -0.47000363, -0.50077529, -0.53062825,
#        -0.55961579, -0.58778666, -0.61518564, -0.64185389, -0.66782937,
#        -0.69314718, -0.71783979, -0.74193734, -0.76546784, -0.78845736,
#        -0.81093022, -0.83290912, -0.85441533, -0.87546874, -0.89608802,
#        -0.91629073, -0.93609336, -0.95551145, -0.97455964, -0.99325177,
#        -1.01160091, -1.02961942, -1.04731899, -1.06471074, -1.08180517,
#        -1.09861229, -1.11514159, -1.13140211, -1.14740245, -1.16315081,
#        -1.178655  , -1.19392247, -1.20896035, -1.22377543, -1.23837423,
#        -1.25276297, -1.2669476 , -1.28093385, -1.29472717, -1.30833282,
#        -1.32175584, -1.33500107, -1.34807315, -1.36097655, -1.37371558,
#        -1.38629436, -1.39871688, -1.41098697, -1.42310833, -1.43508453,
#        -1.44691898, -1.45861502, -1.47017585, -1.48160454, -1.4929041 ,
#        -1.5040774 , -1.51512723, -1.5260563 , -1.53686722, -1.54756251,
#        -1.55814462, -1.56861592, -1.5789787 , -1.58923521, -1.59938758,
#        -1.60943791, -1.61938824, -1.62924054, -1.63899671, -1.64865863,
#        -1.65822808, -1.66770682, -1.67709656, -1.68639895, -1.69561561])
